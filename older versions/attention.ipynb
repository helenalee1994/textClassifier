# %%
test = "recipeClassifierHATT_v4.py"
test += " --gpu=3 --snapshots='../../dir_HugeFiles/snap_0311/attention/'" 
test += " --test='../../dir_HugeFiles/snap_0311/attention/model_e001_v--0.061'" 
# %run $test
# Out:
# Using TensorFlow backend.
# ('Current running on GPU number:', 3)
# tag of tensor board: snap_0311/attention
# /root/anaconda2/lib/python2.7/site-packages/keras/preprocessing/text.py:145: UserWarning: The `nb_words` argument in `Tokenizer` has been renamed `num_words`.
#   warnings.warn('The `nb_words` argument in `Tokenizer` '
# Total 10211 unique tokens.
# ('Shape of data tensor:', (55102, 15, 100))
# ('Shape of label tensor:', (55102, 2))
# Number of positive and negative reviews in traing and validation set
# [32498.   562.]
# [10833.   188.]
# class weight is 57.8
# Total 400000 word vectors.
# WARNING:tensorflow:From /root/anaconda2/lib/python2.7/site-packages/keras/backend/tensorflow_backend.py:1188: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# ...

# %%
train = "recipeClassifierHATT_v4.py"
train += " --gpu=3 --snapshots='../../dir_HugeFiles/snap_0311/attention/'" 
train += " --optm='rmsprop'" 
# %run $train
# Out:
# Using TensorFlow backend.
# ('Current running on GPU number:', 3)
# tag of tensor board: snap_0311/attention
# /root/anaconda2/lib/python2.7/site-packages/keras/preprocessing/text.py:145: UserWarning: The `nb_words` argument in `Tokenizer` has been renamed `num_words`.
#   warnings.warn('The `nb_words` argument in `Tokenizer` '
# Total 10211 unique tokens.
# ('Shape of data tensor:', (55102, 15, 100))
# ('Shape of label tensor:', (55102, 2))
# Number of positive and negative reviews in traing and validation set
# [32498.   562.]
# [10833.   188.]
# class weight is 57.8
# Total 400000 word vectors.
# WARNING:tensorflow:From /root/anaconda2/lib/python2.7/site-packages/keras/backend/tensorflow_backend.py:1188: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# ...

# %%
train = "recipeClassifierHATT_v4.py"
train += " --gpu=3 --snapshots='../../dir_HugeFiles/snap_0311/attention/'" 
train += " --optm='rmsprop'" 
train += " --train='../../dir_HugeFiles/processed_data_0306/GI_full.pickle'"
# %run $train
# Out:
# ('Current running on GPU number:', 3)
# tag of tensor board: snap_0311/attention
# Total 18234 unique tokens.
# ('Shape of data tensor:', (55102, 15, 100))
# ('Shape of label tensor:', (55102, 2))
# Number of positive and negative reviews in traing and validation set
# [32498.   562.]
# [10833.   188.]
# class weight is 57.8
# Total 400000 word vectors.
# model fitting - Hierachical attention network
# ('epoch', 1)
# recipeClassifierHATT_v4.py:214: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   nb_epoch=1, batch_size=opts.batch_size, class_weight={0:1.0,1:class_weights})
# Train on 33060 samples, validate on 11021 samples
# Epoch 1/1
# 33060/33060 [==============================] - 235s - loss: 0.9614 - acc: 0.7643 - val_loss: 0.1795 - val_acc: 0.9296
# :::current prob threshold 0.450
#    positive number: pred 994, true 188
#    -f1 0.212, precision 0.126, recall 0.665
# :::current prob threshold 0.500
#    positive number: pred 822, true 188
# ...
