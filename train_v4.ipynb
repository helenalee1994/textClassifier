# %%
train = "recipeClassifierHATT_v4.py"
train += " --gpu=2 --snapshots='../../dir_HugeFiles/snap_0307/attention/'" 
train += " --resume='../../dir_HugeFiles/snap_0307/attentionmodel_e001_v--0.181'" 
# %run $train
# Out:
# ('Current running on GPU number:', 2)
# tag of tensor board: snap_0307/attention
# Total 10211 unique tokens.
# ('Shape of data tensor:', (55102, 15, 100))
# ('Shape of label tensor:', (55102, 2))
# Number of positive and negative reviews in traing and validation set
# [32498.   562.]
# [10833.   188.]
# class weight is 57.8
# Total 400000 word vectors.
# => loading checkpoint '../../dir_HugeFiles/snap_0307/attentionmodel_e001_v--0.181'
# model fitting - Hierachical attention network
# ('epoch', 1)
# recipeClassifierHATT_v4.py:186: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   num_grid = 20
# Train on 33060 samples, validate on 11021 samples
# Epoch 1/1
# 33060/33060 [==============================] - 217s - loss: 0.7405 - acc: 0.8398 - val_loss: 0.5544 - val_acc: 0.7466
# :::current prob threshold 0.450
#    positive number: pred 3312, true 188
#    -f1 0.105, precision 0.055, recall 0.973
# :::current prob threshold 0.500
# ...

# %%
train = "recipeClassifierHATT_v4.py"
train += " --gpu=2 --snapshots='../../dir_HugeFiles/snap_0307/attention/1e-4'" 
train += "--lr=1e-4"
# %run $train
# Out:
# Using TensorFlow backend.
# ('Current running on GPU number:', 2)
# tag of tensor board: snap_0307/attention/1e-4--lr=1e-4
# /root/anaconda2/lib/python2.7/site-packages/keras/preprocessing/text.py:145: UserWarning: The `nb_words` argument in `Tokenizer` has been renamed `num_words`.
#   warnings.warn('The `nb_words` argument in `Tokenizer` '
# Total 10211 unique tokens.
# ('Shape of data tensor:', (55102, 15, 100))
# ('Shape of label tensor:', (55102, 2))
# Number of positive and negative reviews in traing and validation set
# [32498.   562.]
# [10833.   188.]
# class weight is 57.8
# Total 400000 word vectors.
# WARNING:tensorflow:From /root/anaconda2/lib/python2.7/site-packages/keras/backend/tensorflow_backend.py:1188: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# ...
